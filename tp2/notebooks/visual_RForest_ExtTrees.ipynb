# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ---
# # RANDOM FOREST REGRESSOR
# ---
# ---

# %% [markdown]
# ---
# ### DataFrame para variación de cantidad de estimadores
# ---

# %%
ran_for_var_estimators = pd.DataFrame()

ran_for_var_estimators['#_estimators'] = [5, 10, 20, 40, 60, 80, 100]

ran_for_var_estimators['mae_mean_all'] = [614873, 582412, 563645, 554912, 551432, 550215, 549599]
ran_for_var_estimators['mae_mean_some'] = [616576, 583265, 565624, 556249, 552807, 551089, 550342]
ran_for_var_estimators['mae_std_all'] = [4671, 5203, 3339, 3531, 4289, 4463, 4292]
ran_for_var_estimators['mae_std_some'] = [3371, 4249, 4302, 3974, 4202, 4106, 4172]

ran_for_var_estimators['sco_mean_all'] = [0.758, 0.782, 0.795, 0.800, 0.802, 0.803, 0.803]
ran_for_var_estimators['sco_mean_some'] = [0.758, 0.781, 0.794, 0.800, 0.802, 0.803, 0.803]
ran_for_var_estimators['sco_std_all'] = [0.004, 0.003, 0.002, 0.003, 0.003, 0.003, 0.003]
ran_for_var_estimators['sco_std_some'] = [0.003, 0.003, 0.003, 0.003, 0.003, 0.003, 0.003]

ran_for_var_estimators['time_all'] = [52, 101, 191, 338, 529, 682, 840]
ran_for_var_estimators['time_some'] = [40, 73, 123, 249, 350, 491, 592]

# %% [markdown]
# ---
# ### DataFrame para variación de features
# ---

# %%
ran_for_var_features = pd.DataFrame()

ran_for_var_features['Caso'] = [1, 2, 3, 4, 5, 6, 7]

ran_for_var_features['#_features_all'] = [11, 35, 78, 80, 92, 94, 96]
ran_for_var_features['#_features_some'] = [11, 21, 39, 36, 43, 42, 45]

ran_for_var_features['mae_mean_all'] = [930698, 830863, 636822, 598198, 583082, 578993, 549599]
ran_for_var_features['mae_mean_some'] = [930698, 831781, 641156, 599537, 584963, 580477, 550342]
ran_for_var_features['mae_std_all'] = [5189, 5666, 5069, 5063, 5387, 4707, 4292]
ran_for_var_features['mae_std_some'] = [5189, 5596, 5299, 5056, 5168, 4451, 3954]

ran_for_var_features['sco_mean_all'] = [0.542, 0.615, 0.747, 0.772, 0.784, 0.787, 0.803]
ran_for_var_features['sco_mean_some'] = [0.542, 0.615, 0.745, 0.772, 0.784, 0.786, 0.803]
ran_for_var_features['sco_std_all'] = [0.004, 0.004, 0.003, 0.004, 0.004, 0.003, 0.003]
ran_for_var_features['sco_std_some'] = [0.004, 0.005, 0.003, 0.003, 0.004, 0.003, 0.003]

ran_for_var_features['time_all'] = [164, 286, 653, 705, 808, 828, 840]
ran_for_var_features['time_some'] = [164, 222, 398, 414, 515, 525, 592]

# %% [markdown]
# ---
# ---
# # EXTRA TREES REGRESSOR
# ---
# ---

# %% [markdown]
# ---
# ### DataFrame para variación de cantidad de estimadores
# ---

# %%
ext_tre_var_estimators = pd.DataFrame()

ext_tre_var_estimators['#_estimators'] = [5, 10, 20, 40, 60, 80, 100]

ext_tre_var_estimators['mae_mean_all'] = [612772, 581511, 566138, 557689, 554721, 553192, 552599]
ext_tre_var_estimators['mae_mean_some'] = [617388, 585138, 570113, 560300, 556959, 556191, 555452]
ext_tre_var_estimators['mae_std_all'] = [4622, 4379, 5670, 4431, 4830, 4563, 4364]
ext_tre_var_estimators['mae_std_some'] = [5852, 4443, 4792, 4642, 4718, 4941, 4344]

ext_tre_var_estimators['sco_mean_all'] = [0.757, 0.780, 0.791, 0.796, 0.798, 0.799, 0.800]
ext_tre_var_estimators['sco_mean_some'] = [0.755, 0.779, 0.790, 0.795, 0.798, 0.798, 0.799]
ext_tre_var_estimators['sco_std_all'] = [0.003, 0.003, 0.004, 0.003, 0.003, 0.004, 0.003]
ext_tre_var_estimators['sco_std_some'] = [0.005, 0.004, 0.004, 0.004, 0.004, 0.004, 0.003]

ext_tre_var_estimators['time_all'] = [53, 141, 232, 491, 761, 935, 1149]
ext_tre_var_estimators['time_some'] = [46, 81, 146, 306, 402, 563, 691]

# %% [markdown]
# ### DataFrame para variación de features

# %%
ext_tre_var_features = pd.DataFrame()

ext_tre_var_features['Caso'] = [1, 2, 3, 4, 5, 6, 7]

ext_tre_var_features['#_features_all'] = [11, 35, 78, 80, 92, 94, 96]
ext_tre_var_features['#_features_some'] = [11, 21, 41, 39, 46, 48, 46]

ext_tre_var_features['mae_mean_all'] = [968312, 862316, 640078, 615210, 598200, 590019, 552599]
ext_tre_var_features['mae_mean_some'] = [968312, 863171, 642940, 618170, 601354, 592200, 555452]
ext_tre_var_features['mae_std_all'] = [6219, 5930, 5199, 4832, 6215, 5660, 4364]
ext_tre_var_features['mae_std_some'] = [6219, 5482, 4971, 5115, 5990, 6044, 4344]

ext_tre_var_features['sco_mean_all'] = [0.491, 0.576, 0.736, 0.755, 0.770, 0.776, 0.800]
ext_tre_var_features['sco_mean_some'] = [0.491, 0.575, 0.735, 0.754, 0.769, 0.775, 0.799]
ext_tre_var_features['sco_std_all'] = [0.007, 0.005, 0.004, 0.004, 0.005, 0.004, 0.003]
ext_tre_var_features['sco_std_some'] = [0.007, 0.006, 0.003, 0.004, 0.005, 0.005, 0.003]

ext_tre_var_features['time_all'] = [146, 315, 836, 929, 1046, 1104, 1149]
ext_tre_var_features['time_some'] = [146, 222, 501, 489, 592, 641, 691]

# %% [markdown]
# ---
# ---
# # Variación de cantidad de estimadores
# ---
# ---

# %%
plt.figure(figsize=(15, 5))

plt.plot(ext_tre_var_estimators['#_estimators'], ext_tre_var_estimators['mae_mean_all'], \
         label = 'ET: Todos los Features', \
         color = 'darkred', \
         linewidth = 2)
plt.plot(ext_tre_var_estimators['#_estimators'], ext_tre_var_estimators['mae_mean_some'], \
         label = 'ET: Features filtrados por importancia', \
         color = 'salmon', \
         linewidth = 2)

plt.plot(ran_for_var_estimators['#_estimators'], ran_for_var_estimators['mae_mean_all'], \
         label = 'RF: Todos los Features', \
         color = 'mediumblue', \
         linewidth = 2)
plt.plot(ran_for_var_estimators['#_estimators'], ran_for_var_estimators['mae_mean_some'], \
         label = 'RF: Features filtrados por importancia', \
         color = 'dodgerblue', \
         linewidth = 2)

plt.title("Variación de MAEs promedio según cantidad de estimadores", fontsize=25)
plt.ylabel("Error [$]", fontsize=20)
plt.xlabel("Cantidad de estimadores", fontsize=20)
plt.xticks([5,10,20,40,60,80,100], rotation=0, fontsize=17, ha="center")
plt.yticks(fontsize=17)
plt.legend(loc='upper right', fontsize = 14, framealpha = 1)
plt.grid(color='lightgrey')

plt.show()

# %%
plt.figure(figsize=(7, 4))

plt.plot(ext_tre_var_estimators['#_estimators'], ext_tre_var_estimators['mae_std_all'], \
         label = 'ET: Feat. todos', \
         color = 'darkred', \
         linewidth = 2)
plt.plot(ext_tre_var_estimators['#_estimators'], ext_tre_var_estimators['mae_std_some'], \
         label = 'ET: Feat. filtrados', \
         color = 'salmon', \
         linewidth = 2)

plt.plot(ran_for_var_estimators['#_estimators'], ran_for_var_estimators['mae_std_all'], \
         label = 'RF: Feat. todos', \
         color = 'mediumblue', \
         linewidth = 2)
plt.plot(ran_for_var_estimators['#_estimators'], ran_for_var_estimators['mae_std_some'], \
         label = 'RF: Feat. filtrados', \
         color = 'dodgerblue', \
         linewidth = 2)

plt.title("Desvío estándar del promedio de MAEs\n según cantidad de estimadores", fontsize=25, y = 1.2)
plt.ylabel("Desvío estándar [$]", fontsize=20)
plt.xlabel("Cantidad de estimadores", fontsize=20)
plt.xticks([5,10,20,40,60,80,100], rotation=0, fontsize=17, ha="center")
plt.yticks(fontsize=17)
plt.legend(loc='upper center', fontsize = 12, ncol = 2, framealpha = 1, bbox_to_anchor = (0.5, 1.2))
plt.grid(color='lightgrey')

plt.show()

# %%
plt.figure(figsize=(15, 5))

plt.plot(ext_tre_var_estimators['#_estimators'], ext_tre_var_estimators['sco_mean_all'], \
         label = 'ET: Todos los Features', \
         color = 'darkred', \
         linewidth = 2)
plt.plot(ext_tre_var_estimators['#_estimators'], ext_tre_var_estimators['sco_mean_some'], \
         label = 'ET: Features filtrados por importancia', \
         color = 'salmon', \
         linewidth = 2)

plt.plot(ran_for_var_estimators['#_estimators'], ran_for_var_estimators['sco_mean_all'], \
         label = 'RF: Todos los Features', \
         color = 'mediumblue', \
         linewidth = 2)
plt.plot(ran_for_var_estimators['#_estimators'], ran_for_var_estimators['sco_mean_some'], \
         label = 'RF: Features filtrados por importancia', \
         color = 'dodgerblue', \
         linewidth = 2)

plt.title("Variación del Score según cantidad de estimadores", fontsize=25)
plt.ylabel("Score", fontsize=20)
plt.xlabel("Cantidad de estimadores", fontsize=20)
plt.xticks([5,10,20,40,60,80,100], rotation=0, fontsize=17, ha="center")
plt.yticks(fontsize=17)
plt.legend(loc='lower right', fontsize = 14, framealpha = 1)
plt.grid(color='lightgrey')

plt.show()

# %%
plt.figure(figsize=(7, 4))

plt.plot(ext_tre_var_estimators['#_estimators'], ext_tre_var_estimators['sco_std_all'], \
         label = 'ET: Feat todos', \
         color = 'darkred', \
         linewidth = 2)
plt.plot(ext_tre_var_estimators['#_estimators'], ext_tre_var_estimators['sco_std_some'], \
         label = 'ET: Feat. filtrados', \
         color = 'salmon', \
         linewidth = 2)
plt.plot(ran_for_var_estimators['#_estimators'], ran_for_var_estimators['sco_std_all'], \
         label = 'RF: Feat. todos', \
         color = 'mediumblue', \
         linewidth = 2)
plt.plot(ran_for_var_estimators['#_estimators'], ran_for_var_estimators['sco_std_some'], \
         label = 'RF: Feat. filtrados', \
         color = 'dodgerblue', \
         linewidth = 2)

plt.title("Desvío estándar del promedio de Scores\n según cantidad de estimadores", fontsize=25, y = 1.2)
plt.ylabel("Desvío estándar", fontsize=20)
plt.xlabel("Cantidad de estimadores", fontsize=20)
plt.xticks([5,10,20,40,60,80,100], rotation=0, fontsize=17, ha="center")
plt.yticks(fontsize=17)
plt.legend(loc='upper center', fontsize = 12, ncol = 2, framealpha = 1, bbox_to_anchor = (0.5, 1.2))
plt.grid(color='lightgrey')

plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(ext_tre_var_estimators['#_estimators'], ext_tre_var_estimators['time_all'], \
         label = 'ET: Todos los Features', \
         color = 'darkred', \
         linewidth = 2)
plt.plot(ext_tre_var_estimators['#_estimators'], ext_tre_var_estimators['time_some'], \
         label = 'ET: Features filtrados por importancia', \
         color = 'salmon', \
         linewidth = 2)

plt.plot(ran_for_var_estimators['#_estimators'], ran_for_var_estimators['time_all'], \
         label = 'RF: Todos los Features', \
         color = 'mediumblue', \
         linewidth = 2)
plt.plot(ran_for_var_estimators['#_estimators'], ran_for_var_estimators['time_some'], \
         label = 'RF: Features filtrados por importancia', \
         color = 'dodgerblue', \
         linewidth = 2)

plt.title("Variación de tiempo de cálculo según cantidad de estimadores", fontsize=25)
plt.ylabel("Tiempo [segundos]", fontsize=20)
plt.xlabel("Cantidad de estimadores", fontsize=20)
plt.xticks([5,10,20,40,60,80,100], rotation=0, fontsize=17, ha="center")
plt.yticks(np.arange(0, 1150+1, 60), fontsize=17)
plt.legend(loc='upper left', fontsize = 14, framealpha = 1)
plt.grid(color='lightgrey')

plt.show()

# %% [markdown]
# ---
# ---
# # Variación de cantidad de features
# ---
# ---

# %%
plt.figure(figsize=(15, 5))

plt.plot(ext_tre_var_features['Caso'], ext_tre_var_features['mae_mean_all'], \
         label = 'ET: Todos los Features', \
         color = 'darkred', \
         linewidth = 2)
plt.plot(ext_tre_var_features['Caso'], ext_tre_var_features['mae_mean_some'], \
         label = 'ET: Features filtrados por importancia', \
         color = 'salmon', \
         linewidth = 2)

plt.plot(ran_for_var_features['Caso'], ran_for_var_features['mae_mean_all'], \
         label = 'RF: Todos los Features', \
         color = 'mediumblue', \
         linewidth = 2)
plt.plot(ran_for_var_features['Caso'], ran_for_var_features['mae_mean_some'], \
         label = 'RF: Features filtrados por importancia', \
         color = 'dodgerblue', \
         linewidth = 2)

plt.title("Variación de MAEs promedio según cantidad de features", fontsize=25)
plt.ylabel("Error [$]", fontsize=20)
plt.xlabel("Caso", fontsize=20)
plt.xticks(rotation=0, fontsize=17, ha="center")
plt.yticks(fontsize=17)
plt.legend(loc='upper right', fontsize = 14, framealpha = 1)
plt.grid(color='lightgrey')

plt.show()

# %%
plt.figure(figsize=(7, 4))

plt.plot(ext_tre_var_features['Caso'], ext_tre_var_features['mae_std_all'], \
         label = 'ET: Feat. todos', \
         color = 'darkred', \
         linewidth = 2)
plt.plot(ext_tre_var_features['Caso'], ext_tre_var_features['mae_std_some'], \
         label = 'ET: Feat. filtrados', \
         color = 'salmon', \
         linewidth = 2)

plt.plot(ran_for_var_features['Caso'], ran_for_var_features['mae_std_all'], \
         label = 'RF: Feat. todos', \
         color = 'mediumblue', \
         linewidth = 2)
plt.plot(ran_for_var_features['Caso'], ran_for_var_features['mae_std_some'], \
         label = 'RF: Feat. filtrados', \
         color = 'dodgerblue', \
         linewidth = 2)

plt.title("Desvío estándar del promedio de MAEs\n según cantidad de features", fontsize=25, y = 1.2)
plt.ylabel("Desvío estándar [$]", fontsize=20)
plt.xlabel("Caso", fontsize=20)
plt.xticks(rotation=0, fontsize=17, ha="center")
plt.yticks(fontsize=17)
plt.legend(loc='upper center', fontsize = 12, ncol = 2, framealpha = 1, bbox_to_anchor = (0.5, 1.2))
plt.grid(color='lightgrey')

plt.show()

# %%
plt.figure(figsize=(15, 5))

plt.plot(ext_tre_var_features['Caso'], ext_tre_var_features['sco_mean_all'], \
         label = 'ET: Todos los Features', \
         color = 'darkred', \
         linewidth = 2)
plt.plot(ext_tre_var_features['Caso'], ext_tre_var_features['sco_mean_some'], \
         label = 'ET: Features filtrados por importancia', \
         color = 'salmon', \
         linewidth = 2)

plt.plot(ran_for_var_features['Caso'], ran_for_var_features['sco_mean_all'], \
         label = 'RF: Todos los Features', \
         color = 'mediumblue', \
         linewidth = 2)
plt.plot(ran_for_var_features['Caso'], ran_for_var_features['sco_mean_some'], \
         label = 'RF: Features filtrados por importancia', \
         color = 'dodgerblue', \
         linewidth = 2)

plt.title("Variación del Score según cantidad de features", fontsize=25)
plt.ylabel("Score", fontsize=20)
plt.xlabel("Caso", fontsize=20)
plt.xticks(rotation=0, fontsize=17, ha="center")
plt.yticks(fontsize=17)
plt.legend(loc='lower right', fontsize = 14, framealpha = 1)
plt.grid(color='lightgrey')

plt.show()

# %%
plt.figure(figsize=(7, 4))

plt.plot(ext_tre_var_features['Caso'], ext_tre_var_features['sco_std_all'], \
         label = 'ET: Feat. todos', \
         color = 'darkred', \
         linewidth = 2)
plt.plot(ext_tre_var_features['Caso'], ext_tre_var_features['sco_std_some'], \
         label = 'ET: Feat. filtrados', \
         color = 'salmon', \
         linewidth = 2)

plt.plot(ran_for_var_features['Caso'], ran_for_var_features['sco_std_all'], \
         label = 'RF: Feat. todos', \
         color = 'mediumblue', \
         linewidth = 2)
plt.plot(ran_for_var_features['Caso'], ran_for_var_features['sco_std_some'], \
         label = 'RF: Feat. filtrados', \
         color = 'dodgerblue', \
         linewidth = 2)

plt.title("Desvío estándar del promedio de Scores\n según cantidad de features", fontsize=25, y = 1.2)
plt.ylabel("Desvío estándar", fontsize=20)
plt.xlabel("Caso", fontsize=20)
plt.xticks(rotation=0, fontsize=17, ha="center")
plt.yticks(fontsize=17)
plt.legend(loc='upper center', fontsize = 12, ncol = 2, framealpha = 1, bbox_to_anchor = (0.5, 1.2))
plt.grid(color='lightgrey')

plt.show()

# %%
plt.figure(figsize=(15, 7))

plt.plot(ext_tre_var_features['Caso'], ext_tre_var_features['time_all'], \
         label = 'ET: Todos los Features', \
         color = 'darkred', \
         linewidth = 2)
plt.plot(ext_tre_var_features['Caso'], ext_tre_var_features['time_some'], \
         label = 'ET: Features filtrados por importancia', \
         color = 'salmon', \
         linewidth = 2)

plt.plot(ran_for_var_features['Caso'], ran_for_var_features['time_all'], \
         label = 'RF: Todos los Features', \
         color = 'mediumblue', \
         linewidth = 2)
plt.plot(ran_for_var_features['Caso'], ran_for_var_features['time_some'], \
         label = 'RF: Features filtrados por importancia', \
         color = 'dodgerblue', \
         linewidth = 2)

plt.title("Variación de tiempo de cálculo según cantidad de features", fontsize=25)
plt.ylabel("Tiempo [segundos]", fontsize=20)
plt.xlabel("Caso", fontsize=20)
plt.xticks(rotation=0, fontsize=17, ha="center")
#plt.yticks(fontsize=17)
plt.yticks(np.arange(0, 1150+1, 60), fontsize=17)
#labels = ['todos los features', 'features filtrados por importancia']
#plt.legend(labels, loc='upper right', fontsize = 14)
plt.legend(loc='upper left', fontsize = 14, framealpha = 1)
plt.grid(color='lightgrey')


plt.show()
